# %% [markdown]
# <a href="https://colab.research.google.com/github/rodas020/fightnight-xbmc/blob/master/COMFYUI_BY_RODAS_PINGGY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# #@title Environment Setup

import subprocess
import os
from os import path
import warnings
from IPython.display import clear_output
warnings.filterwarnings('ignore')
from pathlib import Path
from multiprocessing import Process
import sys
import time


OPTIONS = {}

USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE

current_dir = !pwd
BASE = f"{current_dir[0]}/ComfyUI"

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    BASE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive


BASE = os.getcwd()

def download_from_civitai(URL_CITVITAI, PASTA_ONDE_DEVE_SER_INSTALADA, NOME_DO_ARQUIVO):
    tok = COLE_SEU_TOKEB_CTIVITAI_AQUI
    model_url = f"{url}&token={tok}"
    save_path = f"{BASE}/ComfyUI/models/{folder}/{name}"
    get_ipython().system(f'wget -O "{save_path}" "{model_url}"')


def delete_model(PASTA, NOME):
    # %cd $BASE/ComfyUI/models/$folder
    all_names = os.listdir()
    print("O caminho atual é: ", os.getcwd())
    print("Todos os arquivos no diretório atual: ", all_names)

    if name in all_names:
        # %rm $name
        print("O ARQUIVO DO MODELO FOI EXCLUÍDO COM SUCESSO")
    else:
        print("O ARQUIVO DO MODELO FORNECIDO NÃO FOI ENCONTRADO")

# %cd $BASE
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd ComfyUI
get_ipython().system('git pull')
# !pip install - torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu124
# !pip install -r requirements.txt
# !pip install --upgrade gguf
# !pip install bitsandbytes>=0.43.0
# !mamba install openssh -y

# %cd $BASE/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git
# %cd ComfyUI-Manager
get_ipython().system('git pull')
# !pip install -r requirements.txt

# %cd $BASE/ComfyUI/custom_nodes
# !git clone https://github.com/chrisgoringe/cg-use-everywhere.git
# !git clone https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git
# !git clone https://github.com/WASasquatch/was-node-suite-comfyui.git
# !git clone https://github.com/rgthree/rgthree-comfy.git
# !git clone https://github.com/city96/ComfyUI-GGUF
# !git clone https://github.com/crystian/ComfyUI-Crystools.git
# %cd ComfyUI-Crystools
# !pip install -r requirements.txt
# !git clone https://github.com/kijai/ComfyUI-KJNodes.git
# !git clone https://github.com/11cafe/comfyui-workspace-manager.git
# %cd $BASE/ComfyUI/custom_nodes
# !pip install -r requirements.txt


clear_output(wait=True)
# %cd $BASE/ComfyUI

print(f"Current path: {BASE}/ComfyUI")
print("COMFYUI MANAGER + CUSTOM NODES FORAM INSTALADOS COM SUCESSO!👍")
# Out:
# /content/drive/MyDrive/ComfyUI
# Current path: /content/drive/MyDrive/ComfyUI
# COMFYUI MANAGER + CUSTOM NODES FORAM INSTALADOS COM SUCESSO!👍

# %% [markdown]
# # MODELS + CLIP + VAE

# %%
### Flux checkpoint
### flux fp8 模型， 11.9G
model_url = "https://huggingface.co/Kijai/flux-fp8/resolve/main/flux1-dev-fp8.safetensors?download=true"
model_name = "FLUX_fp8.safetensors"
# %cd $BASE/ComfyUI/models/unet
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

### Flux vae
### flux_vae.safetensors, 335MB, 0.3G
model_url = "https://huggingface.co/black-forest-labs/FLUX.1-schnell/resolve/main/ae.safetensors?download=true"
model_name = "FLUX_VAE.safetensors"
# %cd $BASE/ComfyUI/models/vae
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

### Flux clip 1:
## clip_l.safetensors, 246MB, 0.2G
model_url = "https://huggingface.co/GraydientPlatformAPI/flux-clip/resolve/main/clip_l.safetensors?download=true"
model_name = "clip_l.safetensors"
# %cd $BASE/ComfyUI/models/clip
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

### Flux clip 2: t5xxl_fp8, 4.9G
# https://huggingface.co/GraydientPlatformAPI/flux-clip/tree/main
model_url = "https://huggingface.co/GraydientPlatformAPI/flux-clip/resolve/main/t5xxl_fp8_e4m3fn.safetensors?download=true"
model_name = "t5xxl_fp8_e4m3fn.safetensors"
# %cd $BASE/ComfyUI/models/clip
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

# %cd $BASE//ComfyUI
print("FLUX + CLIP + VAE FORAM INSTALADOS COM SUCESSO! 👍")
# Out:
# /content/drive/MyDrive/ComfyUI/models/unet
# --2025-03-27 16:37:49--  https://huggingface.co/Kijai/flux-fp8/resolve/main/flux1-dev-fp8.safetensors?download=true
# Resolving huggingface.co (huggingface.co)... 18.164.174.23, 18.164.174.17, 18.164.174.55, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/fa/7f/fa7f815f89d4b2bcb4ae950e05293cb2f1e1621038b996c0a9829dbdf2a8da85/1be961341be8f5307ef26c787199f80bf4e0de3c1c0b4617095aa6ee5550dfce?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27flux1-dev-fp8.safetensors%3B+filename%3D%22flux1-dev-fp8.safetensors%22%3B&Expires=1743097069&Policy=&Signature=H0DnB6es3XrUEt3GJUqhyG0N0unzq1IGX3K3ZVCYqnlD-QongOp%7EIkvAGuZeT23LoWIxYy9sWUFT-q%7EN1wbuv%7EIWBMVLY4FYCNQmlZIWPBgQeiE11jEkyVxLyyrT9p-yUPQs4Mt0c5RsKiVnSxd8lHrTN4hZdDDpVy1bOTRNLZXYDoOejMkGxTDJ0P2SAtWqDODutcV2LtvDb3%7EPRNiyyrW9bACmYsZyjazHSS53qjmbBQgE9FxEZpHx1L3EQGubh2PFnST-fXW8%7E4xanPQVbannZn9wAIxpNBqiex9JTZuXE6nCmJ9TvZplv-p7dOQfohNaQEHYy0H8C1U66-TZCg__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-03-27 16:37:49--  https://cdn-lfs-us-1.hf.co/repos/fa/7f/fa7f815f89d4b2bcb4ae950e05293cb2f1e1621038b996c0a9829dbdf2a8da85/1be961341be8f5307ef26c787199f80bf4e0de3c1c0b4617095aa6ee5550dfce?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%
:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4893934904 (4.6G) [binary/octet-stream]
# Saving to: ‘t5xxl_fp8_e4m3fn.safetensors’
#
# t5xxl_fp8_e4m3fn.sa 100%[===================>]   4.56G  40.0MB/s    in 3m 23s
#
# 2025-03-27 16:46:32 (23.0 MB/s) - ‘t5xxl_fp8_e4m3fn.safetensors’ saved [4893934904/4893934904]
#
# /content/drive/MyDrive/ComfyUI
# FLUX + CLIP + VAE FORAM INSTALADOS COM SUCESSO! 👍

# %% [markdown]
# # START COMFYUI

# %% [markdown]
# NOTA:
#
# O CARREGAMENTO DEMORA CERCA DE **6 MIN COMPLETO**, AGUARTE E TENTE EXECUTAR SÓ DEPOIS...

# %%
# %cd $BASE/ComfyUI

# !touch log.txt
open('log.txt', 'w').close()
clear_output(wait=True)

def run_app():
    cmd = f"python {BASE}/ComfyUI/main.py & ssh -o StrictHostKeyChecking=no -p 80 -R0:localhost:8188 a.pinggy.io > log.txt"
    get_ipython().system(cmd)

def print_url():
    print("waiting for output")
    time.sleep(2)
    sys.stdout.flush()

    found = False
    with open('log.txt', 'r') as file:
        end_word = '.pinggy.link'
        for line in file:
            start_index = line.find("http:")
            if start_index != -1:
                end_index = line.find(end_word, start_index)
                if end_index != -1:
                    print("😁 😁 😁")
                    print("URL: " + line[start_index:end_index + len(end_word)])
                    print("😁 😁 😁")
                    found = True
    if not found:
        print_url()
    else:
        with open('log.txt', 'r') as file:
            for line in file:
                print(line)

p_app = Process(target=run_app)
p_url = Process(target=print_url)
p_app.start()
p_url.start()
p_app.join()
p_url.join()
# Out:
# waiting for output
# Warning: Permanently added '[a.pinggy.io]:80' (RSA) to the list of known hosts.
# waiting for output
# Allocated port 5 for remote forward to localhost:8188
# 😁 😁 😁
# URL: http://rnpbe-34-143-144-189.a.free.pinggy.link
# 😁 😁 😁
# 7=)0]8;;\                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ┌────────────────────────────┐                                                  │                            │                                                  │ Wait while we prepare the  │                                                  │             UI             │                                                  │                            │                                                  │                            │                                                  │                            │                                                  └────────────────────────────┘                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ]8;;\Youarenotauthenticated.Yourtunnelwillexpirein60minutes.UpgradetoPinggyProtogetunrestrictedtunnels.https://dashboard.pinggy.iohttp://rnpbe-34-143-144-189.a.free.pinggy.linkhttps://rnpbe-34-143-144-189.a.free.pinggy.link                                                                                               Press`h`forkeybindings]8;;\]8;;\Youarenotauthenticated.Yourtunnelwillexpirein60minutes.UpgradetoPinggyProtogetunrestrictedtunnels.https://dashboard.pinggy.iohttp://rnpbe-34-143-144-189.a.free.pinggy.linkhttps://rnpbe-34-143-144-189.a.free.pinggy.linkPress`h`forkeybindings
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-03-27 18:28:51.349
# ** Platform: Linux
# ** Python version: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# [ComfyUI-Manager] 'numpy' dependency were fixed
#
# Prestartup times for custom nodes:
#    0.8 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/rgthree-comfy
#   18.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 40507 MB, total RAM 85480 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 NVIDIA A100-SXM4-40GB : cudaMallocAsync
# Using pytorch attention
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# ComfyUI version: 0.3.27
# ComfyUI frontend version: 1.14.5
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# ### Loading: ComfyUI-Manager (V3.31.8)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.27-7-g0a1f8869 | Released on '2025-03-27'
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# FETCH ComfyRegistry Data: 5/79
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# FETCH ComfyRegistry Data: 10/79
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# connect_to localhost port 8188: failed.
# FETCH ComfyRegistry Data: 15/79
# FETCH ComfyRegistry Data: 20/79
# NumExpr defaulting to 12 threads.
# 2025-03-27 18:33:04.410818: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-27 18:33:04.427868: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743100384.448684    4869 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743100384.455480    4869 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-27 18:33:04.480716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# FETCH ComfyRegistry Data: 25/79
# WAS Node Suite: OpenCV Python FFMPEG support is enabled
# WAS Node Suite Warning: `ffmpeg_bin_path` is not set in `/content/drive/MyDrive/ComfyUI/custom_nodes/was-node-suite-comfyui/was_suite_config.json` config file. Will attempt to use system ffmpeg binaries if available.
# WAS Node Suite: Finished. Loaded 220 nodes successfully.
#
# 	"Art is the light that shines even in the darkest corners." - Unknown
#
# FETCH ComfyRegistry Data: 30/79
# FETCH ComfyRegistry Data: 35/79
# FETCH ComfyRegistry Data: 40/79
# FETCH ComfyRegistry Data: 45/79
# FETCH ComfyRegistry Data: 50/79
# FETCH ComfyRegistry Data: 55/79
# FETCH ComfyRegistry Data: 60/79
#
# [rgthree-comfy] Loaded 42 fantastic nodes. 🎉
#
# FETCH ComfyRegistry Data: 65/79
# FETCH ComfyRegistry Data: 70/79
# [Crystools INFO] Crystools version: 1.22.1
# FETCH ComfyRegistry Data: 75/79
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# [Crystools INFO] CPU: Intel(R) Xeon(R) CPU @ 2.20GHz - Arch: x86_64 - OS: Linux 6.1.85+
# [Crystools INFO] Pynvml (Nvidia) initialized.
# [Crystools INFO] GPU/s:
# [Crystools INFO] 0) NVIDIA A100-SXM4-40GB
# [Crystools INFO] NVIDIA Driver: 550.54.15
#
# Import times for custom nodes:
#    0.9 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    2.8 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/cg-use-everywhere
#    4.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-GGUF
#   12.9 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/was-node-suite-comfyui
#   13.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
#   22.7 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Crystools
#   28.6 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#   31.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/rgthree-comfy
#
# Starting server
#
# To see the GUI go to: http://127.0.0.1:8188
# got prompt
# model weight dtype torch.float16, manual cast: None
# model_type EPS
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.bfloat16
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# Requested to load SD1ClipModel
# loaded completely 38863.675 235.84423828125 True
# Requested to load BaseModel
# loaded completely 38022.18567779541 1639.406135559082 True
# 100% 20/20 [00:07<00:00,  2.85it/s]
# Requested to load AutoencoderKL
# loaded completely 33327.49199295044 159.55708122253418 True
# Prompt executed in 67.82 seconds
# got prompt
# 100% 20/20 [00:06<00:00,  3.06it/s]
# Prompt executed in 8.46 seconds
# got prompt
# 100% 20/20 [00:06<00:00,  3.06it/s]
# Prompt executed in 8.40 seconds

# %% [markdown]
# NOTA:
#
# O CARREGAMENTO DEMORA CERCA DE **6 MIN COMPLETO**, AGUARTE E TENTE EXECUTAR SÓ DEPOIS...
